# %%
from pathlib import Path
from PIL import Image
from transformers import AutoProcessor, VisionEncoderDecoderModel, StoppingCriteria, StoppingCriteriaList
from collections import defaultdict
import fitz
import io
import torch


processor = AutoProcessor.from_pretrained("facebook/nougat-small")
model = VisionEncoderDecoderModel.from_pretrained("facebook/nougat-small")

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)


image_path = Path("/bachelor/nougat_ori/nougat/0.png")
pdf_output_path = Path("/bachelor/nougat_ori/nougat/converted.pdf")


image = Image.open(image_path)
pdf_bytes = io.BytesIO()
image.save(pdf_bytes, format="PDF")
with open(pdf_output_path, "wb") as f:
    f.write(pdf_bytes.getvalue())

print(f"Image successfully converted to PDF: {pdf_output_path}")


def rasterize_paper(
    pdf: Path,
    dpi: int = 96,
    return_pil: bool = True,
    pages: None = None
):
    pillow_images = []
    try:
        pdf = fitz.open(pdf)
        if pages is None:
            pages = range(len(pdf))
        for i in pages:
            page_bytes = pdf[i].get_pixmap(dpi=dpi).pil_tobytes(format="PNG")
            if return_pil:
                pillow_images.append(io.BytesIO(page_bytes))
    except Exception as e:
        print(f"Error rasterizing: {e}")
    return pillow_images


images = rasterize_paper(pdf=pdf_output_path, return_pil=True)
image = Image.open(images[0])


pixel_values = processor(images=image, return_tensors="pt").pixel_values

outputs = model.generate(
    pixel_values.to(device),
    min_length=1,
    max_length=3584,
    bad_words_ids=[[processor.tokenizer.unk_token_id]],
    return_dict_in_generate=True,
    output_scores=True
)

generated = processor.batch_decode(outputs[0], skip_special_tokens=True)[0]
print("\n----- Raw Output -----\n")
print(generated)

generated = generated.replace("\\", "\\")
generated = f"$$\n{generated.strip()}\n$$"

print("\n----- Processed Output -----\n")
print(generated)


output_text_path = Path("outputs/extracted_text.md")
try:
    with open(output_text_path, "w", encoding="utf-8") as file:
        file.write("# Extracted Text from Image\n\n")
        file.write("\n")
        file.write(generated)
        file.write("\n")
    print(f"\nText successfully saved in {output_text_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# Config of the encoder: <class 'transformers.models.donut.modeling_donut_swin.DonutSwinModel'> is overwritten by shared encoder config: DonutSwinConfig {
#   "attention_probs_dropout_prob": 0.0,
#   "depths": [
#     2,
#     2,
#     14,
#     2
#   ],
#   "drop_path_rate": 0.1,
#   "embed_dim": 128,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 1024,
#   "image_size": [
#     896,
#     672
#   ],
#   "initializer_range": 0.02,
#   "layer_norm_eps": 1e-05,
#   "mlp_ratio": 4.0,
#   "model_type": "donut-swin",
#   "num_channels": 3,
#   "num_heads": [
#     4,
#     8,
#     16,
#     32
#   ],
#   "num_layers": 4,
#   "patch_size": 4,
#   "qkv_bias": true,
#   "transformers_version": "4.46.3",
#   "use_absolute_embeddings": false,
#   "window_size": 7
# }
#
# Config of the decoder: <class 'transformers.models.mbart.modeling_mbart.MBartForCausalLM'> is overwritten by shared decoder config: MBartConfig {
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "add_final_layer_norm": true,
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 4,
#   "dropout": 0.1,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "init_std": 0.02,
#   "is_decoder": true,
#   "is_encoder_decoder": false,
#   "max_position_embeddings": 3584,
#   "model_type": "mbart",
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "scale_embedding": true,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.46.3",
#   "use_cache": true,
#   "vocab_size": 50000
# }
# Processing PDF: ..\outputs\pdfs\10_em_81.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 10_em_81.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. A. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K...
# Processing PDF: ..\outputs\pdfs\10_em_86.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 10_em_86.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. A. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K...
# Processing PDF: ..\outputs\pdfs\10_em_87.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 10_em_87.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\10_em_89.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 10_em_89.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. A. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K...
# Processing PDF: ..\outputs\pdfs\11_em_91.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 11_em_91.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. A. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K...
# Processing PDF: ..\outputs\pdfs\11_em_95.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 11_em_95.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\11_em_99.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 11_em_99.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. A. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K...
# Processing PDF: ..\outputs\pdfs\2_em_3.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 2_em_3.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. B. K. Jain, Phys. Rev. D **48**, 1145 (1993).
# * [2] A. B. K. Jain, Phys. Rev...
# Processing PDF: ..\outputs\pdfs\2_em_7.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 2_em_7.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. B. K. Jain, Phys. Rev. **D48** (1993) 2435.
# * [2] A. B. K. Jain, Phys. Rev. ...
# Processing PDF: ..\outputs\pdfs\3_em_11.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 3_em_11.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. B. K. Jain, Phys. Rev. **D48** (1993) 2463.
# * [2] A. B. K. Jain, Phys. Rev. ...
# Processing PDF: ..\outputs\pdfs\3_em_18.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 3_em_18.pdf...
# OCR Text (Page 1): **Figure Captions**
#
# **Figure 1.**
#
# **Figure 2.**
#
# **Figure 3.**
#
# **Figure 4.**
#
# **Figure 5.**
#
# **Fi...
# Processing PDF: ..\outputs\pdfs\4_em_22.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 4_em_22.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\4_em_26.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 4_em_26.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\4_em_27.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 4_em_27.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\5_em_30.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 5_em_30.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. B. K. Jain, Phys. Rev. **D48** (1993) 2435.
# * [2] A. B. K. Jain, Phys. Rev. ...
# Processing PDF: ..\outputs\pdfs\65_alfonso.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_alfonso.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_carlos.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_carlos.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_caue.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_caue.pdf...
# OCR Text (Page 1): **Figure Captions**
#
# **Figure 1.**
#
# **Figure 2.**
#
# **Figure 3.**
#
# **Figure 4.**
#
# **Figure 5.**
#
# **Fi...
# Processing PDF: ..\outputs\pdfs\65_daniel.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_daniel.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_david.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_david.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_edwin.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_edwin.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_Fabricio.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_Fabricio.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_Frank.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_Frank.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_herbert.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_herbert.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_jorge.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_jorge.pdf...
# OCR Text (Page 1): **Figure Captions**
#
# **Figure 1.**
#
# **Figure 2.**
#
# **Figure 3.**
#
# **Figure 4.**
#
# **Figure 5.**
#
# **Fi...
# Processing PDF: ..\outputs\pdfs\65_leissi.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_leissi.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_leo.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_leo.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_maira.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_maira.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_miguel.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_miguel.pdf...
# OCR Text (Page 1): **Figure Captions**
#
# **Figure 1.**
#
# **Figure 2.**
#
# **Figure 3.**
#
# **Figure 4.**
#
# **Figure 5.**
#
# **Fi...
# Processing PDF: ..\outputs\pdfs\65_mijail.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_mijail.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_Nina.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_Nina.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_rosario.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_rosario.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\65_user0.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 65_user0.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\70_alfonso.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 70_alfonso.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. A. Belavin, Phys. Lett. B **246**, 139 (1991).
# * [2] A. Belavin, Phys. Lett....
# Processing PDF: ..\outputs\pdfs\70_carlos.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 70_carlos.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\70_caue.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 70_caue.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\70_daniel.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 70_daniel.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\70_david.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 70_david.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\70_edwin.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 70_edwin.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\7_em_59.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 7_em_59.pdf...
# OCR Text (Page 1): **Figure Captions**
#
# **Figure 1.**
#
# **Figure 2.**
#
# **Figure 3.**
#
# **Figure 4.**
#
# **Figure 5.**
#
# **Fi...
# Processing PDF: ..\outputs\pdfs\8_em_62.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 8_em_62.pdf...
# OCR Text (Page 1): **Figure Captions**
#
# **Figure 1.**
#
# **Figure 2.**
#
# **Figure 3.**
#
# **Figure 4.**
#
# **Figure 5.**
#
# **Fi...
# Processing PDF: ..\outputs\pdfs\8_em_65.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 8_em_65.pdf...
# OCR Text (Page 1): ....
# Processing PDF: ..\outputs\pdfs\9_em_71.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 9_em_71.pdf...
# OCR Text (Page 1): **Figure Captions**
#
# **Figure 1.**
#
# **Figure 2.**
#
# **Figure 3.**
#
# **Figure 4.**
#
# **Figure 5.**
#
# **Fi...
# Processing PDF: ..\outputs\pdfs\9_em_76.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 9_em_76.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. A. Krizhevsky, _The Theory of Nonlinear Systems_, (Cambridge University Pres...
# Processing PDF: ..\outputs\pdfs\9_em_77.pdf
# Page 1 Text: ...
# Rasterizing PDF to images...
# Performing OCR on page 1 of 9_em_77.pdf...
# OCR Text (Page 1): ## References
#
# * [1] A. A. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K. K...
# OCR results saved to ..\outputs\results\ocr_results.csv
